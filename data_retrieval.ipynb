# %% [markdown]
# # Retrieves list of songs from SpotifyCharts

# %%
from fycharts.SpotifyCharts import SpotifyCharts
import pandas as pd

# %%
api = SpotifyCharts()
#api.top200Daily(output_file = "top_200_daily.csv", region = ["us"])
api.top200Daily(output_file = "top_200_2020-03-10.csv", start = "2020-03-10", end = "2020-03-10", region = ["us"])
# Out:
# INFO : 10/03/2020 02:50:01 PM : Extracting top 200 daily for 2020-03-10 - us
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-9d5448a4289b> in <module>
#       1 api = SpotifyCharts()
#       2 #api.top200Daily(output_file = "top_200_daily.csv", region = ["us"])
# ----> 3 api.top200Daily(output_file = "top_200_2020-03-10.csv", start = "2020-03-10", end = "2020-03-10", region = ["us"])
#
# ~/anaconda3/lib/python3.7/site-packages/fycharts/SpotifyCharts.py in top200Daily(self, output_file, output_db, webhook, start, end, region)
#     183                         k = j
#     184                         for region in regions:
# --> 185                                 df = super().helperTop200Daily(theRange, region)
#     186                                 if(output_file is not None):
# ...

# %%
df = pd.read_csv("top_200_daily.csv")
df = df.iloc[0:200]
df["Position"] = pd.to_numeric(df["Position"])

# %%
df
# Out:
#      Position                            Track Name            Artist  \
# 0           1   Bad and Boujee (feat. Lil Uzi Vert)             Migos
# 1           2                             Fake Love             Drake
# 2           3                               Starboy        The Weeknd
# 3           4                                Closer  The Chainsmokers
# 4           5                         Black Beatles      Rae Sremmurd
# ..        ...                                   ...               ...
# 195       196                      Ignition - Remix          R. Kelly
# 196       197                 679 (feat. Remy Boyz)         Fetty Wap
# 197       198                 I Don't Fuck With You          Big Sean
# 198       199  You Can't Hurry Love - 2016 Remaster      Phil Collins
# 199       200                For Free (feat. Drake)         DJ Khaled
#
#      Streams        date region              spotify_id
# 0    1371493  2017-01-01     us  4Km5HrUvYTaSUfiSGPJeQR
# ...

# %%
df["Position"]
# Out:
# True

# %%
df.iloc[29795:29805]
# Out:
#        Position                           Track Name            Artist  \
# 29795       196                          Wyclef Jean        Young Thug
# 29796       197                             Reminder        The Weeknd
# 29797       198                                FEAR.    Kendrick Lamar
# 29798       199                          The Weekend  Brantley Gilbert
# 29799       200                          Candy Paint       Post Malone
# 29800  Position                           Track Name            Artist
# 29801         1  Bad and Boujee (feat. Lil Uzi Vert)             Migos
# 29802         2                            Fake Love             Drake
# 29803         3                              Starboy        The Weeknd
# 29804         4                               Closer  The Chainsmokers
#
#        Streams        date  region              spotify_id
# 29795   158272  2017-05-29      us  55OdqrG8WLmsYyY1jijD9b
# 29796   158031  2017-05-29      us  37F0uwRSrdzkBiuj0D5UHI
# ...

# %%
for chunk in
